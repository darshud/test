# %% [markdown]
# <a href="https://colab.research.google.com/github/darshud/test/blob/main/session-2-code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotnine

from plotnine.data import mpg
from plotnine import ggplot, aes, geom_line, geom_point, element_rect, theme, element_blank

##The "MPG" data set is a subset of the fuel economy data file that the Environment Protection(EPA) makes available on http://fueleconomy.gov. 
##The data set contains fuel economy data from 1999 and 2008 for the 38 popular models cars, with 11 variables and 234 observations.
print(mpg)
# Out:
#     manufacturer   model  displ  year  cyl  ... drv cty  hwy  fl    class
# 0           audi      a4    1.8  1999    4  ...   f  18   29   p  compact
# 1           audi      a4    1.8  1999    4  ...   f  21   29   p  compact
# 2           audi      a4    2.0  2008    4  ...   f  20   31   p  compact
# 3           audi      a4    2.0  2008    4  ...   f  21   30   p  compact
# 4           audi      a4    2.8  1999    6  ...   f  16   26   p  compact
# ..           ...     ...    ...   ...  ...  ...  ..  ..  ...  ..      ...
# 229   volkswagen  passat    2.0  2008    4  ...   f  19   28   p  midsize
# 230   volkswagen  passat    2.0  2008    4  ...   f  21   29   p  midsize
# 231   volkswagen  passat    2.8  1999    6  ...   f  16   26   p  midsize
# 232   volkswagen  passat    2.8  1999    6  ...   f  18   26   p  midsize
# 233   volkswagen  passat    3.6  2008    6  ...   f  17   26   p  midsize
#
# [234 rows x 11 columns]

# %%
## Call the ggplot() function which creates a black canvas
ggplot(mpg)
# Out:
# <ggplot: (8737471880113)>

# %%
## Specify aesthetics mapping which specify how you want to map variables to visual aspects. 
##Let's map displacement and highway miles, and add new layers that are geometric objects.
ggplot(mpg, aes(x="displ", y="hwy"))
# Out:
# <ggplot: (8737471880053)>

# %%
## In this case, we add we add geom_point to add a layer with points elements as the geographic shape to represent data
ggplot(mpg, aes(x="displ", y="hwy"))+geom_point()
# Out:
# <ggplot: (8737470797585)>

# %%
## For example, adding a layer of color
ggplot(data=mpg)+ geom_point(mapping = aes(x="displ", y="hwy", color= "class"))
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if pdtypes.is_categorical(arr):
# <ggplot: (8737470730605)>

# %%
## Adding a border
ggplot(data=mpg)+ geom_point(mapping = aes(x="displ", y="hwy", color= "class"))+theme(panel_border = element_rect(color = "blue", linetype="dashed"))
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if pdtypes.is_categorical(arr):
# <ggplot: (8737470739693)>

# %%
## Removing Background
ggplot(data=mpg)+ geom_point(mapping = aes(x="displ", y="hwy", color= "class"))+theme(panel_background = element_rect(fill="White"))
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if pdtypes.is_categorical(arr):
# <ggplot: (8737470730529)>

# %%
##Removing an element for example,a border
ggplot(data=mpg)+ geom_point(mapping = aes(x="displ", y="hwy", color= "class"))+theme(panel_border = element_blank())
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if pdtypes.is_categorical(arr):
# <ggplot: (8737470615985)>

# %%
##Exercise 1 Make a bar chart that counts number of cars in each type
import pandas as pd
import numpy as np

from plotnine import *

# %matplotlib inline

(ggplot(mpg) + aes(x='class') + geom_bar(size=20) + ggtitle('Number of Cars by Class'))
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   if pdtypes.is_categorical(arr):
# <ggplot: (8737470537689)>

# %%
## Exercise 2 Make a histogram of highway miles per galon

(ggplot(mpg) + aes(x="hwy")+ geom_histogram())
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/stats/stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 11'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# <ggplot: (8737470589049)>

# %%
## Exercise 3 Show relationship between citymiles per galon and highway miles per galon

ggplot(mpg, aes(x="cty", y="hwy"))+geom_point()
# Out:
# <ggplot: (8737470720973)>

# %%
## Exercise 4 Reverse the Scale in Exercise-3

ggplot(mpg, aes(x="cty", y="hwy"))+geom_point()+scale_x_reverse()+scale_y_reverse()
# Out:
# <ggplot: (8737470684693)>

# %%
## Exercise 5 Add a Regression line
ggplot(mpg, aes(x="cty", y="hwy"))+geom_point()+ geom_smooth()
# Out:
# /usr/local/lib/python3.7/dist-packages/plotnine/stats/smoothers.py:168: PlotnineWarning: Confidence intervals are not yet implementedfor lowess smoothings.
#   "for lowess smoothings.", PlotnineWarning)
# <ggplot: (8737470686633)>
